# %%
a= 10 
b=20 
print(a+b)
# Out:
# 30

# %%
print("hello")
# Out:
# hello

# %%
str =" today is the first day" 
print(str[2:])
# Out:
# oday is the first day

# %%
a = ' i like ' 
b = 'python tutorials' 
print(a + b)
print(a* 2) 
print('i' in a) 
print('p' not in a) 
#operations on python
# Out:
#  i like python tutorials
#  i like  i like
# True
# True

# %%
a =5 
b='sri'
c=96.35
d ='A' 
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'str'>

# %%
#numeric datatype 
a = 10 
b = 1+3j 
print(type(a)) 
print(type(b)) 
print('c is a complex number', isinstance(1+3j, complex))
# Out:
# <class 'int'>
# <class 'complex'>
# c is a complex number True

# %%
 #program for finding area of a circle 
 from math import * 
 r = int(input("Enter your radius: ")) 
 pi = 3.14 
 area = pi * r **2 
 print("Area of a circle : " ,area)
# Out:
# Area of a circle :  12.56

# %%
#string datatype 
str = 'Helloworld' 
print(str[1:]) 
print(str[::-1]) 
print(str[8:4:-1])
# Out:
# elloworld
# dlrowolleH
# lrow

# %%
#input function (used to take user input)
name = input("Enter your name: ") 
print("hello" ,name, "good morning") 
#print() function (it displyas text, varibles, expressions on the console.we can print single and multiple variables ,
#  multiple variables are separated by commas)
print(" I am learning python ")
# Out:
# hello supraja good morning
#  I am learning python

# %%
company= "xenderAI" 
print(company)
# Out:
# xenderAI

# %%
name = "sita" 
age = 1700 
print(name , age)
# Out:
# sita 1700

# %%
x,y = input("Enter two numbers: ").split() 
print(x,y)
# Out:
# 25 50

# %%
x,y = input("Enter first name: "), input("Enter second name :") 
print(x,y)
# Out:
# supraja anjani

# %%
x,y = input("Enter two numbers: ").split(",") 
print(x,y)
# Out:
# 10 20

# %%
print("hi")
# Out:
# hi

# %%
#list data type 
a = []
a= [1,2,3] 
print(a) 
b = [24,"supraja",98.35] 
print(b)
# Out:
# [1, 2, 3]
# [24, 'supraja', 98.35]

# %%
a = ["hi", "hello", "hey"] 
#accesing from positive index 
print(a[1]) 
#acessing from negative index 
print(a[-1])
# Out:
# hello
# hey

# %%
#tuple datatype 
#tuple is a collection of ordered python objects.tuple is immutable 
tup1 = (2,"ram", 96.5) 
print(tup1) 
#use index[] operator to access the item in tuple 
print(tup1[1]) 
print(tup1[1:]) 
print(tup1[-2])
# Out:
# (2, 'ram', 96.5)
# ram
# ('ram', 96.5)
# ram

# %%
#boolean datatype 
#two inbuilt value True or False  
#truthy and falsy values are values that evaluate to True or False
print(type(True)) 
print(type(False))
# Out:
# <class 'bool'>
# <class 'bool'>

# %%
s1 = set() 
s1 = set("geeksforgeeks") 
print(s1) 
s2 = set(["geeks", "for," "geeks"]) 
print(s2)
# Out:
# {'e', 's', 'r', 'o', 'f', 'k', 'g'}
# {'geeks', 'for,geeks'}

# %%
#access set items we cannot access the items in set but we can particular item is present or not 
s1 = set("geeksforgeeks")  
print(s1) 
for i in s1: 
    print(i, end='\n') 
print('g' in s1) 
for i in s1: 
    print(i, end=' ') 
print('geeks' in s1)
# Out:
# {'e', 's', 'r', 'o', 'f', 'k', 'g'}
# e
# s
# r
# o
# f
# k
# g
# True
# e s r o f k g False

# %%
#dictionary datatype stores 
#keys must be unique and they are immutable 
#values can be of any type and can be duplicated 
d = {} 
d = { 1: "geeks",2:"for", 3:"geeks"} 
print(d) 

d1 = dict({1:"geeks", 2:"for" , 3:"geeks"}) 
print(d1)
# Out:
# {1: 'geeks', 2: 'for', 3: 'geeks'}
# {1: 'geeks', 2: 'for', 3: 'geeks'}

# %%
# accessing key-value in dictionary  
"""to access items of a dict refers to it key name.key can be used inside square brackets 
.using get() method to access dict elements """ 

d = { 1: "geeks","name":"for", 3:"geeks"} 
print(d["name"]) 
print(d.get(1))
# Out:
# for
# geeks

# %%
#string methods 
#upper - return the string in uppercase 
a = 'Hello World'
print(a.upper()) 
#lower - returns the string in lowercase  
print(a.lower()) 
#strip() - removes the whitespaces from the beginning or the end  
b = " Hello world! " 
print(b.strip())
# Out:
# HELLO WORLD
# hello world
# Hello world!

# %%
#replace method -  replace a string with another string 
a='hello world!' 
print(a.replace("h","j"))  
#split method - splits the string into substrings if it finds the instance of an separator 
a='hello, world!'
print(a.split(",")) 
print(a.split('w'))
# Out:
# jello world!
# ['hello', ' world!']
# ['hello, ', 'orld!']

# %%
#format strings 
age = 36 
txt = f"my name is sita and my age is {age}" 
print(txt)
# Out:
# my name is sita and my age is 36

# %%
price  = 59 
txt =  f"the price is {price} dollars" 
print(txt)
# Out:
# the price is 59 dollars

# %%
price  = 59 
txt =  f"the price is {price:.2f} dollars" 
print(txt)
# Out:
# the price is 59.00 dollars

# %%
txt = "My name is \"supraja \" and i am from \"sivakodu\""
print(txt)
# Out:
# My name is "supraja " and i am from "sivakodu"

# %%
#other escape characters 
#\' single quote 
txt="it\'s alright"
print(txt)  
print("-----------")
# \\ backslash 
txt  = "it will insert one \(backslash)"
print(txt) 
print("-----------")
# \n new line 
txt = "Hello\nWorld!" 
print(txt) 
print("-----------")
# \r carrier return 
txt = "Hello\rWorld!" 
print(txt) 
print("-----------") 
# \t tab 
print("Hello\tWorld")  
print("-----------") 
# \b backspace 
print("Hello \bWorld")
# Out:
# it's alright
# -----------
# it will insert one \(backslash)
# -----------
# Hello
# World!
# -----------
# World!
# -----------
# Hello	World
# -----------
# HelloWorld

# %%
a="helLoworld!" 
print(a.capitalize()) 
print(a.casefold())
# Out:
# Helloworld!
# helloworld!

# %%
txt = "center" 
print(txt.center(20)) 
print(txt.center(20,"a"))
# Out:
#        center
# aaaaaaacenteraaaaaaa

# %%
txt = "I love apples, apple are my favorite fruit"

x = txt.count("apple")

print(x)
# Out:
# 2

# %%
txt = " ai the ai " 
x = txt.count("ai") 
print(x)
# Out:
# 2

# %%
txt = "My name is Ståle"

x = txt.encode()

print(x)
# Out:
# b'My name is St\xc3\xa5le'

# %%
txt = "hello, welcome to my world" 
x = txt.endswith("my world") 
print(x)
# Out:
# True

# %%
#string formatting 
a = 5
b = "My name is XYZ & AND MY AGE IS {}"
print(b.format(a))
# Out:
# My name is XYZ & AND MY AGE IS 5

# %%
c = "My name is {0} and my age is {1} .Also i have one sibling who's age is {2}" 
print(c.format("sri",20,25))
# Out:
# My name is sri and my age is 20 .Also i have one sibling who's age is 25

# %%
s = 'BVC' 
print(s.lower())
print(s.upper())
print("split all words".split()) 
print(' '.join(['happy','new','year'])) 
print('happy new year'.find('new')) 
print('new year'.replace('new','chinese'))
# Out:
# bvc
# BVC
# ['split', 'all', 'words']
# happy new year
# 6
# chinese year

# %%
s1 = input("Enter main string: ")
s2 = input("Enter substring: ")
if(s1.find(s2) != -1):
    print(s2,"found in" ,s1) 
else:
    print(s2,"not found in", s1)
# Out:
# string found in welcome to string

# %%
str = 'python'
print(str.capitalize())
# Out:
# Python

# %%
str  = "python is awesome isn't it"
substr = "is"
count = str.count(substr)
print("Count = ",count)
# Out:
# Count =  2

# %%
str = "12345"
print(str.isdigit()) 
str = "ab123"
print(str.isalpha())
# Out:
# True
# False

# %%
str = "sita"
print(str.isalpha()) 
str = "abc123" 
print(str.isalnum())
# Out:
# True
# True

# %%
str = "abc"
print(str.islower())
str = "ABC"
print(str.isupper()) 
str = "bank"
print(str.swapcase())
# Out:
# True
# True
# BANK

# %%
var1 = 45
var2 = 55
var3 = 65
print("max_value  =", max(var1,var2,var3))
# Out:
# max_value  = 65

# %%
var1 = int(input("Enter first number : "))
var2 = int(input("Enter second number : ")) 
var3 = int(input("Enter third number : ")) 
max_value = max(var1,var2,var3) 
print(max_value)
# Out:
# 78

# %%
a = [1,'BVC', 98, 96.35] 
print(a) 
print(type(a))
# Out:
# [1, 'BVC', 98, 96.35]
# <class 'list'>

# %%
a=[[30], [20.2 ,'python']] 
print(a[0][0]) 
print(a[1][0])
print(a[1][1]) 
print(a[-1][1])
# Out:
# 30
# 20.2
# python
# python

# %%
list1 = [10, 39.35, "welcome", 1]
